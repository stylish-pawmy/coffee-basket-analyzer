# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth
import json

# %%
with open('../data/processed/basket_item_sets.json', 'r') as f:
    transactions = json.load(f)
    
transactions
# Out:
# [['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Hot chocolate'],
#  ['Drip coffee'],
#  ['Brewed Chai tea', 'Scone'],
#  ['Drip coffee'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Brewed Green tea', 'Scone'],
#  ['Brewed herbal tea'],
#  ['Hot chocolate'],
#  ['Hot chocolate'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea', 'Biscotti'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea', 'Biscotti'],
#  ['Brewed herbal tea', 'Pastry'],
#  ['Barista Espresso'],
#  ['Barista Espresso'],
#  ['Organic brewed coffee'],
#  ['Organic brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea'],
#  ['Brewed herbal tea'],
#  ['Drip coffee'],
#  ['Hot chocolate', 'Scone'],
#  ['Brewed Chai tea', 'Scone'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Brewed Black tea'],
#  ['Drip coffee'],
#  ['Brewed Green tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Green tea'],
#  ['Brewed herbal tea'],
#  ['Organic brewed coffee'],
#  ['Hot chocolate'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea'],
#  ['Premium brewed coffee'],
#  ['Premium brewed coffee', 'Biscotti'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea', 'Scone'],
#  ['Brewed Chai tea'],
#  ['Drip coffee'],
#  ['Barista Espresso'],
#  ['Barista Espresso'],
#  ['Barista Espresso', 'Biscotti'],
#  ['Brewed Black tea'],
#  ['Brewed Green tea'],
#  ['Barista Espresso', 'Scone'],
#  ['Premium brewed coffee'],
#  ['Drip coffee'],
#  ['Brewed herbal tea'],
#  ['Drip coffee'],
#  ['Gourmet brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Organic brewed coffee', 'Pastry'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Organic brewed coffee'],
#  ['Drip coffee'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea'],
#  ['Hot chocolate', 'Biscotti'],
#  ['Brewed Green tea'],
#  ['Premium brewed coffee', 'Scone'],
#  ['Hot chocolate'],
#  ['Hot chocolate'],
#  ['Premium brewed coffee'],
#  ['Brewed Black tea'],
#  ['Hot chocolate'],
#  ['Brewed Green tea'],
#  ['Drip coffee', 'Pastry'],
#  ['Barista Espresso', 'Biscotti'],
#  ['Drip coffee'],
#  ['Barista Espresso', 'Pastry'],
#  ['Brewed Green tea', 'Pastry'],
#  ['Barista Espresso'],
#  ['Hot chocolate'],
#  ['Brewed Black tea'],
#  ['Hot chocolate'],
#  ['Brewed Green tea', 'Scone'],
#  ['Brewed Green tea'],
#  ['Brewed herbal tea'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Brewed Black tea'],
#  ['Hot chocolate'],
#  ['Gourmet brewed coffee'],
#  ['Hot chocolate', 'Scone'],
#  ['Brewed Black tea'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Premium brewed coffee', 'Scone'],
#  ['Drip coffee'],
#  ['Drip coffee'],
#  ['Brewed Black tea', 'Scone'],
#  ['Brewed Chai tea', 'Pastry'],
#  ['Hot chocolate', 'Pastry'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee'],
#  ['Barista Espresso'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea', 'Scone'],
#  ['Organic brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Brewed herbal tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Brewed Black tea', 'Scone'],
#  ['Hot chocolate'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Black tea'],
#  ['Premium brewed coffee', 'Pastry'],
#  ['Premium brewed coffee'],
#  ['Brewed Green tea'],
#  ['Brewed herbal tea'],
#  ['Organic brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Brewed Green tea'],
#  ['Drip coffee'],
#  ['Brewed herbal tea'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Black tea'],
#  ['Barista Espresso'],
#  ['Premium brewed coffee'],
#  ['Brewed Black tea'],
#  ['Organic brewed coffee'],
#  ['Brewed Black tea'],
#  ['Hot chocolate'],
#  ['Drip coffee'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea'],
#  ['Barista Espresso'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Hot chocolate'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Drip coffee'],
#  ['Gourmet brewed coffee', 'Pastry'],
#  ['Barista Espresso'],
#  ['Gourmet brewed coffee'],
#  ['Hot chocolate'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Hot chocolate', 'Scone'],
#  ['Brewed Chai tea', 'Pastry'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea', 'Pastry'],
#  ['Brewed herbal tea'],
#  ['Organic brewed coffee'],
#  ['Hot chocolate'],
#  ['Brewed Green tea'],
#  ['Brewed herbal tea'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Organic brewed coffee'],
#  ['Brewed Black tea', 'Scone'],
#  ['Organic brewed coffee'],
#  ['Brewed herbal tea'],
#  ['Organic brewed coffee', 'Scone'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Drip coffee'],
#  ['Hot chocolate'],
#  ['Drip coffee'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea', 'Pastry'],
#  ['Drip coffee'],
#  ['Gourmet brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Barista Espresso'],
#  ['Drip coffee'],
#  ['Brewed Green tea'],
#  ['Hot chocolate'],
#  ['Hot chocolate'],
#  ['Gourmet brewed coffee'],
#  ['Organic brewed coffee'],
#  ['Barista Espresso'],
#  ['Gourmet brewed coffee'],
#  ['Organic brewed coffee'],
#  ['Barista Espresso'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea'],
#  ['Brewed herbal tea'],
#  ['Brewed herbal tea'],
#  ['Premium brewed coffee'],
#  ['Brewed Chai tea', 'Scone'],
#  ['Brewed Chai tea', 'Biscotti'],
#  ['Organic brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Drip coffee'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso'],
#  ['Gourmet brewed coffee'],
#  ['Drip coffee'],
#  ['Brewed herbal tea'],
#  ['Brewed herbal tea'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee', 'Pastry'],
#  ['Brewed Green tea'],
#  ['Premium brewed coffee'],
#  ['Barista Espresso'],
#  ['Organic brewed coffee', 'Biscotti'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso'],
#  ['Drip coffee'],
#  ['Drip coffee', 'Pastry'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea'],
#  ['Drip coffee'],
#  ['Premium brewed coffee'],
#  ['Brewed herbal tea'],
#  ['Brewed Black tea'],
#  ['Barista Espresso'],
#  ['Brewed Chai tea', 'Pastry'],
#  ['Barista Espresso', 'Scone'],
#  ['Hot chocolate'],
#  ['Drip coffee'],
#  ['Hot chocolate'],
#  ['Brewed herbal tea'],
#  ['Brewed Black tea', 'Scone'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea'],
#  ['Brewed herbal tea'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso'],
#  ['Barista Espresso'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Brewed herbal tea'],
#  ['Barista Espresso'],
#  ['Premium brewed coffee'],
#  ['Hot chocolate'],
#  ['Brewed Black tea'],
#  ['Brewed Green tea'],
#  ['Brewed Black tea'],
#  ['Drip coffee', 'Pastry'],
#  ['Brewed Black tea'],
#  ['Brewed herbal tea'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Brewed herbal tea'],
#  ['Barista Espresso'],
#  ['Barista Espresso'],
#  ['Organic brewed coffee'],
#  ['Brewed herbal tea'],
#  ['Drip coffee'],
#  ['Hot chocolate'],
#  ['Barista Espresso', 'Pastry'],
#  ['Drip coffee'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee'],
#  ['Barista Espresso'],
#  ['Hot chocolate'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso'],
#  ['Organic brewed coffee'],
#  ['Brewed Black tea'],
#  ['Hot chocolate'],
#  ['Hot chocolate'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea', 'Scone'],
#  ['Brewed herbal tea'],
#  ['Gourmet brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee', 'Biscotti'],
#  ['Barista Espresso', 'Biscotti'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea'],
#  ['Premium brewed coffee'],
#  ['Brewed Green tea'],
#  ['Barista Espresso'],
#  ['Premium brewed coffee'],
#  ['Barista Espresso', 'Biscotti'],
#  ['Gourmet brewed coffee'],
#  ['Drip coffee'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Black tea'],
#  ['Barista Espresso'],
#  ['Barista Espresso'],
#  ['Premium brewed coffee'],
#  ['Brewed Green tea'],
#  ['Brewed herbal tea'],
#  ['Drip coffee'],
#  ['Drip coffee'],
#  ['Brewed herbal tea'],
#  ['Brewed herbal tea'],
#  ['Barista Espresso'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Premium brewed coffee'],
#  ['Drip coffee'],
#  ['Drip coffee'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea'],
#  ['Brewed herbal tea'],
#  ['Organic brewed coffee'],
#  ['Barista Espresso'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Hot chocolate'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Green tea'],
#  ['Drip coffee'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea'],
#  ['Brewed herbal tea', 'Scone'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea', 'Pastry'],
#  ['Brewed Chai tea'],
#  ['Brewed herbal tea'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Hot chocolate', 'Biscotti'],
#  ['Premium brewed coffee'],
#  ['Brewed Black tea'],
#  ['Brewed Black tea'],
#  ['Premium brewed coffee'],
#  ['Brewed Green tea'],
#  ['Organic brewed coffee'],
#  ['Hot chocolate'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Premium brewed coffee', 'Pastry'],
#  ['Barista Espresso'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso', 'Scone'],
#  ['Brewed Green tea', 'Scone'],
#  ['Premium brewed coffee'],
#  ['Brewed Black tea'],
#  ['Barista Espresso'],
#  ['Hot chocolate'],
#  ['Premium brewed coffee', 'Biscotti'],
#  ['Barista Espresso', 'Scone'],
#  ['Brewed Green tea', 'Pastry'],
#  ['Brewed Chai tea'],
#  ['Brewed Green tea', 'Biscotti'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea', 'Pastry'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee', 'Biscotti'],
#  ['Premium brewed coffee'],
#  ['Organic brewed coffee'],
#  ['Premium brewed coffee', 'Biscotti'],
#  ['Hot chocolate'],
#  ['Brewed herbal tea'],
#  ['Barista Espresso'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso'],
#  ['Brewed Chai tea', 'Biscotti'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee', 'Scone'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee', 'Scone'],
#  ['Drip coffee'],
#  ['Premium brewed coffee'],
#  ['Organic brewed coffee'],
#  ['Drip coffee'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea', 'Biscotti'],
#  ['Brewed Green tea'],
#  ['Hot chocolate'],
#  ['Barista Espresso'],
#  ['Gourmet brewed coffee', 'Scone'],
#  ['Brewed Chai tea'],
#  ['Hot chocolate'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Hot chocolate'],
#  ['Drip coffee'],
#  ['Brewed Chai tea'],
#  ['Drip coffee'],
#  ['Brewed Black tea'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee'],
#  ['Barista Espresso'],
#  ['Organic brewed coffee'],
#  ['Drip coffee'],
#  ['Gourmet brewed coffee'],
#  ['Drip coffee'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso', 'Pastry'],
#  ['Brewed herbal tea'],
#  ['Barista Espresso'],
#  ['Barista Espresso'],
#  ['Drip coffee'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee'],
#  ['Hot chocolate'],
#  ['Barista Espresso'],
#  ['Organic brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Brewed Black tea'],
#  ['Barista Espresso'],
#  ['Brewed Green tea', 'Scone'],
#  ['Brewed herbal tea'],
#  ['Barista Espresso'],
#  ['Brewed Black tea'],
#  ['Brewed herbal tea'],
#  ['Hot chocolate'],
#  ['Barista Espresso'],
#  ['Organic brewed coffee'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea'],
#  ['Brewed Green tea'],
#  ['Barista Espresso'],
#  ['Brewed Chai tea'],
#  ['Hot chocolate'],
#  ['Organic brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Barista Espresso'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea', 'Scone'],
#  ['Hot chocolate'],
#  ['Brewed herbal tea'],
#  ['Drip coffee'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso', 'Pastry'],
#  ['Organic brewed coffee'],
#  ['Brewed Black tea', 'Pastry'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Organic brewed coffee'],
#  ['Hot chocolate'],
#  ['Brewed Black tea'],
#  ['Hot chocolate'],
#  ['Hot chocolate', 'Biscotti'],
#  ['Organic brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Brewed herbal tea'],
#  ['Brewed herbal tea'],
#  ['Barista Espresso'],
#  ['Organic brewed coffee'],
#  ['Organic brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Organic brewed coffee'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso'],
#  ['Hot chocolate', 'Scone'],
#  ['Hot chocolate'],
#  ['Premium brewed coffee', 'Scone'],
#  ['Gourmet brewed coffee', 'Pastry'],
#  ['Brewed Green tea'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Drip coffee', 'Scone'],
#  ['Hot chocolate'],
#  ['Drip coffee'],
#  ['Barista Espresso'],
#  ['Barista Espresso'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Organic brewed coffee'],
#  ['Drip coffee'],
#  ['Organic brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Barista Espresso'],
#  ['Brewed Black tea'],
#  ['Barista Espresso'],
#  ['Hot chocolate'],
#  ['Gourmet brewed coffee', 'Biscotti'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee', 'Scone'],
#  ['Gourmet brewed coffee'],
#  ['Hot chocolate'],
#  ['Brewed herbal tea'],
#  ['Drip coffee'],
#  ['Drip coffee'],
#  ['Organic brewed coffee'],
#  ['Brewed herbal tea'],
#  ['Brewed herbal tea'],
#  ['Brewed Black tea'],
#  ['Brewed Black tea'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Black tea'],
#  ['Organic brewed coffee', 'Scone'],
#  ['Organic brewed coffee', 'Scone'],
#  ['Organic brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Organic brewed coffee'],
#  ['Barista Espresso'],
#  ['Brewed Green tea'],
#  ['Drip coffee'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso'],
#  ['Gourmet brewed coffee'],
#  ['Brewed herbal tea'],
#  ['Gourmet brewed coffee', 'Pastry'],
#  ['Premium brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea'],
#  ['Brewed Black tea'],
#  ['Brewed Green tea'],
#  ['Brewed herbal tea'],
#  ['Brewed Black tea', 'Scone'],
#  ['Organic brewed coffee', 'Biscotti'],
#  ['Hot chocolate'],
#  ['Drip coffee'],
#  ['Brewed herbal tea', 'Biscotti'],
#  ['Brewed herbal tea'],
#  ['Brewed Black tea'],
#  ['Brewed herbal tea', 'Scone'],
#  ['Organic brewed coffee'],
#  ['Brewed herbal tea'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Black tea'],
#  ['Hot chocolate'],
#  ['Brewed herbal tea'],
#  ['Organic brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso', 'Scone'],
#  ['Premium brewed coffee', 'Pastry'],
#  ['Brewed Chai tea'],
#  ['Drip coffee'],
#  ['Gourmet brewed coffee'],
#  ['Drip coffee'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee', 'Scone'],
#  ['Brewed Green tea', 'Pastry'],
#  ['Brewed Black tea'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea'],
#  ['Drip coffee'],
#  ['Brewed Chai tea', 'Scone'],
#  ['Drip coffee'],
#  ['Brewed herbal tea', 'Scone'],
#  ['Gourmet brewed coffee', 'Biscotti'],
#  ['Drip coffee'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee', 'Scone'],
#  ['Gourmet brewed coffee'],
#  ['Hot chocolate'],
#  ['Brewed Black tea'],
#  ['Hot chocolate'],
#  ['Drip coffee'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Drip coffee'],
#  ['Brewed herbal tea'],
#  ['Organic brewed coffee'],
#  ['Barista Espresso'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Barista Espresso'],
#  ['Brewed Chai tea'],
#  ['Hot chocolate'],
#  ['Organic brewed coffee'],
#  ['Brewed Green tea'],
#  ['Brewed Green tea'],
#  ['Drip coffee'],
#  ['Hot chocolate', 'Scone'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Brewed Green tea'],
#  ['Drip coffee'],
#  ['Organic brewed coffee'],
#  ['Barista Espresso', 'Biscotti'],
#  ['Drip coffee'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Black tea'],
#  ['Organic brewed coffee'],
#  ['Hot chocolate'],
#  ['Brewed Black tea', 'Scone'],
#  ['Gourmet brewed coffee', 'Scone'],
#  ['Brewed herbal tea'],
#  ['Gourmet brewed coffee'],
#  ['Drip coffee'],
#  ['Brewed Green tea'],
#  ['Brewed Black tea'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Brewed Green tea'],
#  ['Brewed herbal tea'],
#  ['Barista Espresso'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee', 'Biscotti'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Barista Espresso'],
#  ['Gourmet brewed coffee'],
#  ['Drip coffee'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Drip coffee'],
#  ['Barista Espresso'],
#  ['Brewed Green tea'],
#  ['Brewed Black tea', 'Scone'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Hot chocolate'],
#  ['Organic brewed coffee', 'Pastry'],
#  ['Hot chocolate', 'Scone'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee', 'Scone'],
#  ['Drip coffee', 'Pastry'],
#  ['Barista Espresso'],
#  ['Barista Espresso'],
#  ['Premium brewed coffee'],
#  ['Barista Espresso'],
#  ['Brewed Green tea'],
#  ['Organic brewed coffee'],
#  ['Drip coffee'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea', 'Pastry'],
#  ['Barista Espresso'],
#  ['Hot chocolate'],
#  ['Barista Espresso'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Green tea'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea', 'Scone'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee'],
#  ['Hot chocolate'],
#  ['Drip coffee'],
#  ['Hot chocolate', 'Pastry'],
#  ['Brewed Black tea'],
#  ['Barista Espresso'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Brewed herbal tea', 'Pastry'],
#  ['Drip coffee'],
#  ['Barista Espresso'],
#  ['Brewed Black tea'],
#  ['Barista Espresso'],
#  ['Brewed Chai tea'],
#  ['Drip coffee'],
#  ['Barista Espresso'],
#  ['Brewed Green tea', 'Scone'],
#  ['Brewed Chai tea'],
#  ['Drip coffee'],
#  ['Organic brewed coffee'],
#  ['Barista Espresso'],
#  ['Gourmet brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Brewed Green tea', 'Biscotti'],
#  ['Barista Espresso'],
#  ['Barista Espresso'],
#  ['Brewed Chai tea'],
#  ['Premium brewed coffee'],
#  ['Barista Espresso'],
#  ['Brewed Green tea'],
#  ['Gourmet brewed coffee'],
#  ['Organic brewed coffee', 'Pastry'],
#  ['Drip coffee'],
#  ['Organic brewed coffee', 'Scone'],
#  ['Gourmet brewed coffee'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso', 'Scone'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea'],
#  ['Brewed Green tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed herbal tea'],
#  ['Hot chocolate'],
#  ['Brewed Black tea'],
#  ['Brewed Black tea'],
#  ['Brewed herbal tea', 'Biscotti'],
#  ['Hot chocolate'],
#  ['Barista Espresso'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea'],
#  ['Premium brewed coffee'],
#  ['Brewed Chai tea', 'Biscotti'],
#  ['Hot chocolate', 'Scone'],
#  ['Brewed Green tea'],
#  ['Drip coffee'],
#  ['Gourmet brewed coffee', 'Biscotti'],
#  ['Brewed Green tea'],
#  ['Brewed Chai tea', 'Biscotti'],
#  ['Brewed Green tea', 'Biscotti'],
#  ['Drip coffee'],
#  ['Brewed herbal tea'],
#  ['Brewed Green tea', 'Pastry'],
#  ['Brewed herbal tea', 'Scone'],
#  ['Brewed Chai tea', 'Scone'],
#  ['Brewed Green tea'],
#  ['Brewed Green tea'],
#  ['Premium brewed coffee'],
#  ['Barista Espresso'],
#  ['Premium brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea', 'Scone'],
#  ['Brewed Chai tea'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Hot chocolate'],
#  ['Brewed herbal tea'],
#  ['Brewed Black tea', 'Scone'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Premium brewed coffee'],
#  ['Barista Espresso'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea'],
#  ['Barista Espresso'],
#  ['Organic brewed coffee'],
#  ['Brewed Green tea'],
#  ['Gourmet brewed coffee', 'Scone'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Hot chocolate', 'Scone'],
#  ['Brewed Black tea'],
#  ['Organic brewed coffee'],
#  ['Organic brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee', 'Pastry'],
#  ['Brewed Chai tea'],
#  ['Premium brewed coffee'],
#  ['Drip coffee'],
#  ['Drip coffee', 'Biscotti'],
#  ['Brewed Chai tea'],
#  ['Premium brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea', 'Pastry'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee', 'Brewed Chai tea'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Drip coffee'],
#  ['Brewed Black tea'],
#  ['Premium brewed coffee', 'Scone'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Black tea'],
#  ['Brewed Black tea'],
#  ['Organic brewed coffee'],
#  ['Premium brewed coffee', 'Scone'],
#  ['Drip coffee'],
#  ['Barista Espresso'],
#  ['Drip coffee'],
#  ['Organic brewed coffee'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee', 'Scone'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed herbal tea'],
#  ['Brewed herbal tea'],
#  ['Organic brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea', 'Scone'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee', 'Biscotti'],
#  ['Brewed Green tea'],
#  ['Gourmet brewed coffee'],
#  ['Drip coffee'],
#  ['Brewed Green tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Green tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed herbal tea', 'Pastry'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Black tea'],
#  ['Organic brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Hot chocolate', 'Pastry'],
#  ['Barista Espresso'],
#  ['Organic brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Hot chocolate'],
#  ['Premium brewed coffee'],
#  ['Brewed Green tea'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea', 'Biscotti'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Brewed Green tea', 'Biscotti'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee', 'Pastry'],
#  ['Hot chocolate', 'Pastry'],
#  ['Gourmet brewed coffee', 'Scone'],
#  ['Hot chocolate'],
#  ['Brewed Chai tea'],
#  ['Gourmet brewed coffee', 'Pastry'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Organic brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Premium brewed coffee', 'Pastry'],
#  ['Gourmet brewed coffee', 'Scone'],
#  ['Barista Espresso'],
#  ['Brewed Black tea'],
#  ['Brewed herbal tea', 'Scone'],
#  ['Brewed Green tea'],
#  ['Gourmet brewed coffee'],
#  ['Hot chocolate'],
#  ['Hot chocolate'],
#  ['Barista Espresso'],
#  ['Premium brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Hot chocolate', 'Scone'],
#  ['Brewed Green tea', 'Biscotti'],
#  ['Brewed Chai tea', 'Scone'],
#  ['Drip coffee'],
#  ['Brewed Black tea'],
#  ['Drip coffee'],
#  ['Brewed Black tea'],
#  ['Hot chocolate'],
#  ['Barista Espresso'],
#  ['Barista Espresso', 'Scone'],
#  ['Brewed Black tea', 'Pastry'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Drip coffee'],
#  ['Drip coffee', 'Scone'],
#  ['Drip coffee'],
#  ['Drip coffee', 'Biscotti'],
#  ['Organic brewed coffee'],
#  ['Premium brewed coffee'],
#  ['Barista Espresso'],
#  ['Brewed Black tea'],
#  ['Barista Espresso'],
#  ['Brewed Black tea'],
#  ['Brewed Chai tea', 'Biscotti'],
#  ['Gourmet brewed coffee'],
#  ['Gourmet brewed coffee', 'Pastry'],
#  ['Drip coffee', 'Biscotti'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea', 'Scone'],
#  ['Organic brewed coffee'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea', 'Scone'],
#  ['Gourmet brewed coffee'],
#  ['Hot chocolate', 'Pastry'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Barista Espresso'],
#  ['Hot chocolate'],
#  ['Brewed herbal tea'],
#  ['Barista Espresso', 'Biscotti'],
#  ['Barista Espresso'],
#  ['Brewed herbal tea'],
#  ['Drip coffee'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Organic brewed coffee'],
#  ['Brewed Black tea'],
#  ['Gourmet brewed coffee'],
#  ['Hot chocolate'],
#  ['Barista Espresso'],
#  ['Drip coffee'],
#  ['Barista Espresso', 'Scone'],
#  ['Hot chocolate', 'Scone'],
#  ['Barista Espresso'],
#  ['Hot chocolate'],
#  ['Gourmet brewed coffee'],
#  ['Brewed Chai tea', 'Biscotti', 'Premium brewed coffee'],
#  ['Gourmet brewed coffee', 'Scone'],
#  ['Hot chocolate'],
#  ['Drip coffee'],
#  ['Hot chocolate'],
#  ['Brewed Black tea', 'Scone'],
#  ['Drip coffee'],
#  ['Brewed herbal tea'],
#  ['Brewed Chai tea'],
#  ['Brewed Chai tea'],
#  ['Hot chocolate'],
#  ['Brewed Black tea'],
#  ['Barista Espresso', 'Scone'],
#  ...]

# %%
te = TransactionEncoder()

te_ary = te.fit(transactions).transform(transactions)

df = pd.DataFrame(te_ary, columns=te.columns_)

df
# Out:
#         Barista Espresso  Biscotti  Black tea  Brewed Black tea  \
# 0                  False     False      False             False
# 1                  False     False      False             False
# 2                  False     False      False             False
# 3                  False     False      False             False
# 4                  False     False      False             False
# ...                  ...       ...        ...               ...
# 116785             False     False      False             False
# 116786             False     False      False             False
# 116787             False     False      False              True
# 116788             False     False      False             False
# 116789              True     False      False             False
#
#         Brewed Chai tea  Brewed Green tea  Brewed herbal tea  Chai tea  \
# 0                 False             False              False     False
# 1                  True             False              False     False
# 2                 False             False              False     False
# 3                 False             False              False     False
# 4                  True             False              False     False
# ...                 ...               ...                ...       ...
# 116785            False             False               True     False
# 116786            False             False               True     False
# 116787            False             False              False     False
# 116788            False             False               True     False
# 116789            False             False              False     False
#
#         Clothing  Drinking Chocolate  ...  Housewares  Organic Beans  \
# 0          False               False  ...       False          False
# 1          False               False  ...       False          False
# 2          False               False  ...       False          False
# 3          False               False  ...       False          False
# 4          False               False  ...       False          False
# ...          ...                 ...  ...         ...            ...
# 116785     False               False  ...       False          False
# 116786     False               False  ...       False          False
# 116787     False               False  ...       False          False
# 116788     False               False  ...       False          False
# 116789     False               False  ...       False          False
#
#         Organic Chocolate  Organic brewed coffee  Pastry  Premium Beans  \
# 0                   False                  False   False          False
# 1                   False                  False   False          False
# 2                   False                  False   False          False
# 3                   False                  False   False          False
# 4                   False                  False   False          False
# ...                   ...                    ...     ...            ...
# 116785              False                  False   False          False
# 116786              False                  False   False          False
# 116787              False                  False   False          False
# 116788              False                  False   False          False
# 116789              False                  False   False          False
#
#         Premium brewed coffee  Regular syrup  Scone  Sugar free syrup
# 0                       False          False  False             False
# 1                       False          False  False             False
# 2                       False          False  False             False
# 3                       False          False  False             False
# 4                       False          False   True             False
# ...                       ...            ...    ...               ...
# 116785                  False          False  False             False
# 116786                  False          False  False             False
# 116787                  False          False  False             False
# 116788                  False          False  False             False
# 116789                  False           True  False             False
#
# [116790 rows x 29 columns]

# %% [markdown]
# ## FP-Growth
#
# The **Frequent Pattern Growth** algorithm is an efficient alternative to Apriori for mining frequent itemsets. Unlike Apriori, FP-Growth avoids candidate generation by using a **divide-and-conquer** approach and a data structure called the **FP-tree**.
#
# The algorithm begins by constructing the FP-tree from the transaction database, where items are arranged in a frequency-descending order to maximize tree compression. Each node in the tree represents an item, and paths represent itemsets.
#
# Once the tree is built, FP-Growth extracts frequent itemsets by recursively partitioning the tree into conditional FP-trees, which represent the dataset projected onto specific frequent items. The process continues until all frequent itemsets are identified.
#
# FP-Growth is particularly well-suited for large datasets with many transactions, as it avoids the computational overhead of repeatedly scanning the database, among the main drawbacks of Apriori.

# %%
tidsets = fpgrowth(df, min_support=0.003)

# %%
tidsets
# Out:
#      support     itemsets
# 0   0.144704         (13)
# 1   0.146811          (4)
# 2   0.098108         (17)
# 3   0.072429         (10)
# 4   0.086352         (27)
# 5   0.139473          (0)
# 6   0.097046          (3)
# 7   0.048523          (5)
# 8   0.096207          (6)
# 9   0.048848          (1)
# 10  0.057025         (23)
# 11  0.072677         (22)
# 12  0.069544         (25)
# 13  0.042555         (26)
# 14  0.003134         (12)
# 15  0.003553         (20)
# 16  0.015498         (28)
# 17  0.003793          (7)
# 18  0.004504         (19)
# 19  0.005309     (10, 27)
# 20  0.011645      (27, 4)
# 21  0.007946     (17, 27)
# 22  0.007586      (27, 6)
# 23  0.016251      (0, 27)
# 24  0.007543      (3, 27)
# 25  0.011088     (27, 13)
# 26  0.004007      (27, 5)
# 27  0.007192       (1, 4)
# 28  0.004504       (1, 6)
# 29  0.003819      (1, 25)
# 30  0.006576       (0, 1)
# 31  0.004410      (1, 17)
# 32  0.003228      (1, 22)
# 33  0.006944      (1, 13)
# 34  0.003151      (1, 10)
# 35  0.004649       (1, 3)
# 36  0.005000      (6, 23)
# 37  0.003973     (22, 23)
# 38  0.003596     (10, 23)
# 39  0.007021      (0, 23)
# 40  0.007475      (4, 23)
# 41  0.004940     (17, 23)
# 42  0.003322     (25, 23)
# 43  0.006182     (13, 23)
# 44  0.004838      (3, 23)
# 45  0.005703     (27, 22)
# 46  0.005488     (25, 27)
# 47  0.042341      (0, 26)
# 48  0.003588     (26, 27)
# 49  0.003511  (0, 26, 27)
# 50  0.015404      (0, 28)

# %% [markdown]
# For better readability, we added the names of the items based on their id.

# %%
itemset_names = []
for itemset in tidsets['itemsets']:
    itemset_names.append(', '.join([te.columns_[index] for index in itemset]))

# %%
tidsets = pd.concat([tidsets, pd.DataFrame(itemset_names, columns=['labels'])], axis=1)

# %%
tidsets
# Out:
#      support     itemsets                                  labels
# 0   0.144704         (13)                   Gourmet brewed coffee
# 1   0.146811          (4)                         Brewed Chai tea
# 2   0.098108         (17)                           Hot chocolate
# 3   0.072429         (10)                             Drip coffee
# 4   0.086352         (27)                                   Scone
# 5   0.139473          (0)                        Barista Espresso
# 6   0.097046          (3)                        Brewed Black tea
# 7   0.048523          (5)                        Brewed Green tea
# 8   0.096207          (6)                       Brewed herbal tea
# 9   0.048848          (1)                                Biscotti
# 10  0.057025         (23)                                  Pastry
# 11  0.072677         (22)                   Organic brewed coffee
# 12  0.069544         (25)                   Premium brewed coffee
# 13  0.042555         (26)                           Regular syrup
# 14  0.003134         (12)                           Gourmet Beans
# 15  0.003553         (20)                           Organic Beans
# 16  0.015498         (28)                        Sugar free syrup
# 17  0.003793          (7)                                Chai tea
# 18  0.004504         (19)                              Housewares
# 19  0.005309     (10, 27)                      Drip coffee, Scone
# 20  0.011645      (27, 4)                  Scone, Brewed Chai tea
# 21  0.007946     (17, 27)                    Hot chocolate, Scone
# 22  0.007586      (27, 6)                Scone, Brewed herbal tea
# 23  0.016251      (0, 27)                 Barista Espresso, Scone
# 24  0.007543      (3, 27)                 Brewed Black tea, Scone
# 25  0.011088     (27, 13)            Scone, Gourmet brewed coffee
# 26  0.004007      (27, 5)                 Scone, Brewed Green tea
# 27  0.007192       (1, 4)               Biscotti, Brewed Chai tea
# 28  0.004504       (1, 6)             Biscotti, Brewed herbal tea
# 29  0.003819      (1, 25)         Biscotti, Premium brewed coffee
# 30  0.006576       (0, 1)              Barista Espresso, Biscotti
# 31  0.004410      (1, 17)                 Biscotti, Hot chocolate
# 32  0.003228      (1, 22)         Biscotti, Organic brewed coffee
# 33  0.006944      (1, 13)         Biscotti, Gourmet brewed coffee
# 34  0.003151      (1, 10)                   Biscotti, Drip coffee
# 35  0.004649       (1, 3)              Biscotti, Brewed Black tea
# 36  0.005000      (6, 23)               Brewed herbal tea, Pastry
# 37  0.003973     (22, 23)           Organic brewed coffee, Pastry
# 38  0.003596     (10, 23)                     Drip coffee, Pastry
# 39  0.007021      (0, 23)                Barista Espresso, Pastry
# 40  0.007475      (4, 23)                 Brewed Chai tea, Pastry
# 41  0.004940     (17, 23)                   Hot chocolate, Pastry
# 42  0.003322     (25, 23)           Premium brewed coffee, Pastry
# 43  0.006182     (13, 23)           Gourmet brewed coffee, Pastry
# 44  0.004838      (3, 23)                Brewed Black tea, Pastry
# 45  0.005703     (27, 22)            Scone, Organic brewed coffee
# 46  0.005488     (25, 27)            Premium brewed coffee, Scone
# 47  0.042341      (0, 26)         Barista Espresso, Regular syrup
# 48  0.003588     (26, 27)                    Regular syrup, Scone
# 49  0.003511  (0, 26, 27)  Barista Espresso, Regular syrup, Scone
# 50  0.015404      (0, 28)      Barista Espresso, Sugar free syrup

# %%
tidsets
# Out:
#      support     itemsets                                  labels
# 0   0.144704         (13)                   Gourmet brewed coffee
# 1   0.146811          (4)                         Brewed Chai tea
# 2   0.098108         (17)                           Hot chocolate
# 3   0.072429         (10)                             Drip coffee
# 4   0.086352         (27)                                   Scone
# 5   0.139473          (0)                        Barista Espresso
# 6   0.097046          (3)                        Brewed Black tea
# 7   0.048523          (5)                        Brewed Green tea
# 8   0.096207          (6)                       Brewed herbal tea
# 9   0.048848          (1)                                Biscotti
# 10  0.057025         (23)                                  Pastry
# 11  0.072677         (22)                   Organic brewed coffee
# 12  0.069544         (25)                   Premium brewed coffee
# 13  0.042555         (26)                           Regular syrup
# 14  0.003134         (12)                           Gourmet Beans
# 15  0.003553         (20)                           Organic Beans
# 16  0.015498         (28)                        Sugar free syrup
# 17  0.003793          (7)                                Chai tea
# 18  0.004504         (19)                              Housewares
# 19  0.005309     (10, 27)                      Drip coffee, Scone
# 20  0.011645      (27, 4)                  Scone, Brewed Chai tea
# 21  0.007946     (17, 27)                    Hot chocolate, Scone
# 22  0.007586      (27, 6)                Scone, Brewed herbal tea
# 23  0.016251      (0, 27)                 Barista Espresso, Scone
# 24  0.007543      (3, 27)                 Brewed Black tea, Scone
# 25  0.011088     (27, 13)            Scone, Gourmet brewed coffee
# 26  0.004007      (27, 5)                 Scone, Brewed Green tea
# 27  0.007192       (1, 4)               Biscotti, Brewed Chai tea
# 28  0.004504       (1, 6)             Biscotti, Brewed herbal tea
# 29  0.003819      (1, 25)         Biscotti, Premium brewed coffee
# 30  0.006576       (0, 1)              Barista Espresso, Biscotti
# 31  0.004410      (1, 17)                 Biscotti, Hot chocolate
# 32  0.003228      (1, 22)         Biscotti, Organic brewed coffee
# 33  0.006944      (1, 13)         Biscotti, Gourmet brewed coffee
# 34  0.003151      (1, 10)                   Biscotti, Drip coffee
# 35  0.004649       (1, 3)              Biscotti, Brewed Black tea
# 36  0.005000      (6, 23)               Brewed herbal tea, Pastry
# 37  0.003973     (22, 23)           Organic brewed coffee, Pastry
# 38  0.003596     (10, 23)                     Drip coffee, Pastry
# 39  0.007021      (0, 23)                Barista Espresso, Pastry
# 40  0.007475      (4, 23)                 Brewed Chai tea, Pastry
# 41  0.004940     (17, 23)                   Hot chocolate, Pastry
# 42  0.003322     (25, 23)           Premium brewed coffee, Pastry
# 43  0.006182     (13, 23)           Gourmet brewed coffee, Pastry
# 44  0.004838      (3, 23)                Brewed Black tea, Pastry
# 45  0.005703     (27, 22)            Scone, Organic brewed coffee
# 46  0.005488     (25, 27)            Premium brewed coffee, Scone
# 47  0.042341      (0, 26)         Barista Espresso, Regular syrup
# 48  0.003588     (26, 27)                    Regular syrup, Scone
# 49  0.003511  (0, 26, 27)  Barista Espresso, Regular syrup, Scone
# 50  0.015404      (0, 28)      Barista Espresso, Sugar free syrup

# %% [markdown]
# ### Exporting model

# %%
tidsets.to_csv('../models/fp-growth-results.csv')
